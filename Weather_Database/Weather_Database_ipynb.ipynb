# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['hobart',
#  'ushuaia',
#  'karasburg',
#  'cape town',
#  'barrow',
#  'huarmey',
#  'qaanaaq',
#  'rocha',
#  'port alfred',
#  'hinton',
#  'rikitea',
#  'tuktoyaktuk',
#  'bredasdorp',
#  'norman wells',
#  'paamiut',
#  'samfya',
#  'albany',
#  'mehamn',
#  'yumen',
#  'dzaoudzi',
#  'luangwa',
#  'marabba',
#  'tautira',
#  'punta arenas',
#  'bara',
#  'kahului',
#  'goundam',
#  'atuona',
#  'asau',
#  'saldanha',
#  'taolanaro',
#  'bluff',
#  'iskateley',
#  'mount isa',
#  'katsiveli',
#  'cajamarca',
#  'nikolskoye',
#  'ahipara',
#  'mys shmidta',
#  'sirsi',
#  'hermanus',
#  'bengkulu',
#  'lagoa',
#  'tougue',
#  'touros',
#  'grindavik',
#  'alyangula',
#  'provideniya',
#  'busselton',
#  'belushya guba',
#  'luderitz',
#  'ponta do sol',
#  'vanimo',
#  'kiama',
#  'russell',
#  'saskylakh',
#  'adelaide',
#  'waingapu',
#  'kapaa',
#  'timberlake',
#  'nanortalik',
#  'arraial do cabo',
#  'new norfolk',
#  'honningsvag',
#  'calama',
#  'tiksi',
#  'barentsburg',
#  'chitradurga',
#  'khatanga',
#  'port-cartier',
#  'jamestown',
#  'inta',
#  'kaitangata',
#  'kuldiga',
#  'victoria',
#  'dagumba-an',
#  'bol',
#  'tsihombe',
#  'nizhneyansk',
#  'losone',
#  'kut chap',
#  'marion',
#  'bathsheba',
#  'illoqqortoormiut',
#  'vaini',
#  'kodiak',
#  'mataura',
#  'tuatapere',
#  'itarema',
#  'viligili',
#  'pevek',
#  'san bartolome',
#  'dabat',
#  'manado',
#  'sioux lookout',
#  'pallapatti',
#  'trelew',
#  'fort nelson',
#  'boyuibe',
#  'sirnak',
#  'saleaula',
#  'nhulunbuy',
#  'suoyarvi',
#  'grand gaube',
#  'chuy',
#  'senno',
#  'pokhara',
#  'belyy yar',
#  'port hardy',
#  'paka',
#  'cidreira',
#  'avarua',
#  'katsuura',
#  'elko',
#  'souillac',
#  'fukuma',
#  'port blair',
#  'okhotsk',
#  'manavalakurichi',
#  'karpathos',
#  'casa nova',
#  'la primavera',
#  'padang',
#  'linqiong',
#  'beringovskiy',
#  'puerto ayora',
#  'siguiri',
#  'mount pleasant',
#  'san patricio',
#  'mahajanga',
#  'alto araguaia',
#  'acapulco',
#  'aix-les-bains',
#  'cabo san lucas',
#  'hofn',
#  'berlevag',
#  'yellowknife',
#  'talnakh',
#  'la ronge',
#  'houma',
#  'mangrol',
#  'urumqi',
#  'hualmay',
#  'lasa',
#  'carnarvon',
#  'buin',
#  'hilo',
#  'umea',
#  'dingle',
#  'ribeira grande',
#  'ilulissat',
#  'mar del plata',
#  'sao felix do xingu',
#  'dickinson',
#  'bocas del toro',
#  'iqaluit',
#  'vila do maio',
#  'corrente',
#  'koulikoro',
#  'narsaq',
#  'castro',
#  'saint george',
#  'tasiilaq',
#  'omboue',
#  'leningradskiy',
#  'dikson',
#  'butaritari',
#  'san juan',
#  'luwingu',
#  'tete',
#  'sentyabrskiy',
#  'tateyama',
#  'sao filipe',
#  'krasnyy yar',
#  'airai',
#  'bonavista',
#  'coihaique',
#  'torbay',
#  'faanui',
#  'bethel',
#  'larion',
#  'san quintin',
#  'mahebourg',
#  'santa rosa',
#  'mandan',
#  'khasan',
#  'andenes',
#  'port elizabeth',
#  'lakes entrance',
#  'nexo',
#  'caravelas',
#  'linares',
#  'east london',
#  'geraldton',
#  'babstovo',
#  'jumla',
#  'lata',
#  'nador',
#  'camacha',
#  'kidal',
#  'tanete',
#  'iberia',
#  'lenger',
#  'kenitra',
#  'eydhafushi',
#  'igrim',
#  'monrovia',
#  'gat',
#  'khair',
#  'egvekinot',
#  'ostrovnoy',
#  'fortuna',
#  'yuci',
#  'okha',
#  'coolum beach',
#  'longyearbyen',
#  'ambilobe',
#  'queimadas',
#  'maragogi',
#  'satitoa',
#  'oneonta',
#  'thompson',
#  'kavaratti',
#  'muros',
#  'naryan-mar',
#  'champerico',
#  'harsud',
#  'esperance',
#  'qasigiannguit',
#  'tura',
#  'okato',
#  'pitimbu',
#  'lazaro cardenas',
#  'bahir dar',
#  'inndyr',
#  'pahalgam',
#  'petropavlovsk-kamchatskiy',
#  'astana',
#  'alofi',
#  'maua',
#  'ramsar',
#  'miraflores',
#  'mindelo',
#  'nikolsk',
#  'haines junction',
#  'marystown',
#  'vilcun',
#  'imeni zhelyabova',
#  'muana',
#  'jalu',
#  'kenai',
#  'samusu',
#  'vila velha',
#  'hagersville',
#  'nadym',
#  'saint-philippe',
#  'slonim',
#  'hithadhoo',
#  'mount gambier',
#  'paldiski',
#  'faya',
#  'luanda',
#  'kuche',
#  'abha',
#  'bilibino',
#  'iranshahr',
#  'broome',
#  'batemans bay',
#  'charters towers',
#  'roma',
#  'wanning',
#  'grenfell',
#  'fairbanks',
#  'burica',
#  'ordu',
#  'nerang',
#  'shelburne',
#  'hamilton',
#  'chokurdakh',
#  'balakliya',
#  'walvis bay',
#  'kintinku',
#  'lorengau',
#  'atikokan',
#  'lukovetskiy',
#  'brigantine',
#  'flinders',
#  'nguiu',
#  'coahuayana',
#  'oriximina',
#  'palmer',
#  'makakilo city',
#  'saint-augustin',
#  'powell river',
#  'gazanjyk',
#  'namibe',
#  'lyngdal',
#  'kabinda',
#  'amderma',
#  'eyl',
#  'toliary',
#  'tecoanapa',
#  'necochea',
#  'hokitika',
#  'tambo',
#  'tubmanburg',
#  'los llanos de aridane',
#  'aklavik',
#  'voskresenskoye',
#  'haibowan',
#  'murray bridge',
#  'severo-kurilsk',
#  'altay',
#  'semnan',
#  'seoul',
#  'vanavara',
#  'serebryansk',
#  'khilok',
#  'french harbor',
#  'severo-yeniseyskiy',
#  'krasnyy',
#  'mezen',
#  'cherskiy',
#  'upernavik',
#  'san carlos de bariloche',
#  'klaksvik',
#  'meulaboh',
#  'canico',
#  'redcar',
#  'srednekolymsk',
#  'laguna',
#  'gornopravdinsk',
#  'yuzhno-yeniseyskiy',
#  'mirina',
#  'anadyr',
#  'cockburn town',
#  'cabra',
#  'kuroishi',
#  'qobustan',
#  'inverness',
#  'salalah',
#  'half moon bay',
#  'obregon',
#  'guerrero negro',
#  'namatanai',
#  'bulata',
#  'suntar',
#  'mana',
#  'portland',
#  'praia da vitoria',
#  'rungata',
#  'krasnoyarka',
#  'comodoro rivadavia',
#  'riyadh',
#  'sorland',
#  'broken hill',
#  'bambous virieux',
#  'solenzo',
#  'muncar',
#  'mrirt',
#  'ayan',
#  'tres arroyos',
#  'shawinigan',
#  'komsomolskiy',
#  'bairiki',
#  'pisco',
#  'chuchkovo',
#  'ukiah',
#  'ostersund',
#  'elk city',
#  'keflavik',
#  'pokrovsk-uralskiy',
#  'kawana waters',
#  'sobolevo',
#  'ocampo',
#  'jamai',
#  'hailey',
#  'kazalinsk',
#  'nola',
#  'jiroft',
#  'karaul',
#  'ternate',
#  'bubaque',
#  'tessalit',
#  'clyde river',
#  'leh',
#  'abu zabad',
#  'lompoc',
#  'dakar',
#  'whitehorse',
#  'ndioum',
#  'millington',
#  'ballina',
#  'pusztaszabolcs',
#  'skjervoy',
#  'mutoko',
#  'mentougou',
#  'carballo',
#  'carutapera',
#  'vestmannaeyjar',
#  'san cristobal',
#  'nykoping',
#  'hambantota',
#  'mandalgovi',
#  'louisbourg',
#  'rio gallegos',
#  'qaqortoq',
#  'lebu',
#  'samana',
#  'coquimbo',
#  'ugoofaaru',
#  'basco',
#  'birao',
#  'barcelos',
#  'paragominas',
#  'teguldet',
#  'attawapiskat',
#  'te anau',
#  'cunduacan',
#  'altona',
#  'morgan city',
#  'zhezkazgan',
#  'upata',
#  'chumikan',
#  'new richmond',
#  'aykhal',
#  'daru',
#  'sitka',
#  'candolim',
#  'asyut',
#  'isla mujeres',
#  'moranbah',
#  'vardo',
#  'taoudenni',
#  'brae',
#  'caraballeda',
#  'mountain home',
#  'najran',
#  'yirol',
#  'banda aceh',
#  'gashua',
#  'tome-acu',
#  'porteirinha',
#  'isangel',
#  'solnechnyy',
#  'oranjemund',
#  'gorno-chuyskiy',
#  'muroto',
#  'cumaribo',
#  'huambo',
#  'baykit',
#  'eureka',
#  'myshkin',
#  'crestview',
#  'diego de almagro',
#  'areosa',
#  'kishtwar',
#  'marsh harbour',
#  'bolungarvik',
#  'irtyshskiy',
#  'markova',
#  'baruun-urt',
#  'rajapur',
#  'mangai',
#  'sotik',
#  'karamea',
#  'nantucket',
#  'vilhena',
#  'tieli',
#  'santa marta',
#  'talipan',
#  'bababe',
#  'puerto narino',
#  'the valley',
#  'kruisfontein',
#  'garchitorena',
#  'ixtapa',
#  'xichang',
#  'lamu',
#  'cairns',
#  'maningrida',
#  'algiers',
#  'mendahara',
#  'kashi',
#  'codrington',
#  'utiroa',
#  'ammapettai',
#  'hare bay',
#  'migori',
#  'mae hong son',
#  'port lincoln',
#  'mawlaik',
#  'preobrazheniye',
#  'ishigaki',
#  'porto novo',
#  'bikramganj',
#  'marsa matruh',
#  'denpasar',
#  'vila',
#  'bonthe',
#  'olga',
#  'pangnirtung',
#  'tabiauea',
#  'flin flon',
#  'sasebo',
#  'arman',
#  'hasaki',
#  'gigmoto',
#  'samarai',
#  'koungou',
#  'venado tuerto',
#  'port augusta',
#  'swellendam',
#  'lahaina',
#  'burlington',
#  'aketi',
#  'hendijan',
#  'yar-sale',
#  'grand river south east',
#  'houston',
#  'storforshei',
#  'puerto del rosario',
#  'bhandaria',
#  'pudozh',
#  'shingu',
#  'chernyshevskiy',
#  'sambava',
#  'kalabo',
#  'banyo',
#  'roald',
#  'itoman',
#  'umzimvubu',
#  'korla',
#  'georgetown',
#  'manokwari',
#  'el cocuy',
#  'general roca',
#  'los rastrojos',
#  'dudinka',
#  'paoua',
#  'prado',
#  'richards bay',
#  'toul',
#  'aras',
#  'kudahuvadhoo',
#  'jining',
#  'antigonish',
#  'dundee',
#  'royan',
#  'yefimovskiy',
#  'babu',
#  'prusanky',
#  'santo amaro das brotas',
#  'mayor pablo lagerenza',
#  'bingerville',
#  'northam',
#  'ust-kamchatsk',
#  'havre-saint-pierre',
#  'ziarat',
#  'warqla',
#  'krasnoselkup',
#  'mbour',
#  'jinka',
#  'camopi',
#  'miles city',
#  'kabo',
#  'vao',
#  'burgeo',
#  'danielskuil',
#  'cayenne',
#  'el reno',
#  'mackay',
#  'pilot butte',
#  'bargal',
#  'aquiraz',
#  'khorol',
#  'yantarnyy',
#  'surt',
#  'terrace',
#  'long',
#  'bilma',
#  'shimoda',
#  'sarakhs',
#  'balikpapan',
#  'ulkan',
#  'atlantic city',
#  'buraydah',
#  'pitkyaranta',
#  'fare',
#  'pandan',
#  'beidao',
#  'mbini',
#  'hirara',
#  'kalmunai',
#  'miquelon',
#  'hingatungan',
#  'manaus',
#  'vila franca do campo',
#  'marcona',
#  'tongliao',
#  'sosnovo-ozerskoye',
#  'alice springs',
#  'andilamena',
#  'erenhot',
#  'gari',
#  'certesti',
#  'chaykovskaya',
#  'saint-louis',
#  'mamakan',
#  'poum',
#  'tefe',
#  'presidencia roque saenz pena',
#  'abu jubayhah',
#  'gamba',
#  'sakaiminato',
#  'naranjal',
#  'san andres',
#  'antofagasta',
#  'krasnaya gora',
#  'luganville',
#  'sao gabriel da cachoeira',
#  'galveston',
#  'cabedelo',
#  'biak',
#  'matale',
#  'kamenskoye',
#  'cambridge',
#  'abalak',
#  'goure',
#  'razole',
#  'davila',
#  'kaeo',
#  'pareora',
#  'buala',
#  'bexhill',
#  'pueblo nuevo',
#  'vaitupu',
#  'tasbuget',
#  'kamaishi',
#  'saint-claude',
#  'toba tek singh',
#  'tumannyy',
#  'svetlyy',
#  'teknaf',
#  'ardakan',
#  'nome',
#  'teya',
#  'gladstone',
#  'raudeberg',
#  'naruto',
#  'taltal',
#  'ust-maya',
#  'emba',
#  'belmonte',
#  'batagay-alyta',
#  'le port',
#  'zatoka',
#  'dong hoi',
#  'ponta pora',
#  'parkersburg',
#  'southbridge',
#  'ivanava',
#  'tabou',
#  'cloquet',
#  'peniche',
#  'parrita',
#  'macas',
#  'margate',
#  'nicolas bravo',
#  'kavieng',
#  'rancho palos verdes',
#  'general pico',
#  'valdagno',
#  'verkhoyansk',
#  'saint-joseph',
#  'innisfail',
#  'warmbad',
#  'nchelenge',
#  'naze',
#  'la romana',
#  'avera',
#  'aromashevo',
#  'san fernando',
#  'meyungs',
#  'kysyl-syr',
#  'sukhumi',
#  'deputatskiy',
#  'norsup',
#  'kahama',
#  'orotukan',
#  'kununurra',
#  'kamphaeng phet',
#  'boueni',
#  'kharan',
#  'ust-omchug',
#  'skeldon',
#  'yarmouth',
#  'inuvik',
#  'palabuhanratu',
#  'westport',
#  'terrace bay',
#  'morro bay',
#  'abu samrah',
#  'beloha',
#  'homer',
#  'juniyah',
#  'inongo',
#  'grand-santi',
#  'sola',
#  'dolbeau',
#  'glubokoe',
#  'pacasmayo',
#  'khoy',
#  'huai mek',
#  'male',
#  'atasu',
#  'syamzha',
#  'halalo',
#  'kasongo',
#  'barra',
#  'perigueux',
#  'filadelfia',
#  'bocaranga',
#  'atamanovka',
#  'manuk mangkaw',
#  'puerto colombia',
#  'gbarnga',
#  'altagracia de orituco',
#  'sorong',
#  'teguise',
#  'farkhor',
#  'concarneau',
#  'mangochi',
#  'tiganasi',
#  'adrar',
#  'hutchinson',
#  'marawi',
#  'fort-shevchenko',
#  'sooke',
#  'bundaberg',
#  'sarh',
#  'pacific grove',
#  'lexington park',
#  'myitkyina',
#  'nisko',
#  'oktyabrskoye',
#  'santa isabel',
#  'plettenberg bay',
#  'longuenesse',
#  'quang ngai',
#  'la ligua',
#  'placido de castro',
#  'vredendal',
#  'lindi']

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Weather": city_desc,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | karasburg
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | huarmey
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | rocha
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | hinton
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | paamiut
# Processing Record 16 of Set 1 | samfya
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | mehamn
# Processing Record 19 of Set 1 | yumen
# Processing Record 20 of Set 1 | dzaoudzi
# Processing Record 21 of Set 1 | luangwa
# Processing Record 22 of Set 1 | marabba
# Processing Record 23 of Set 1 | tautira
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bara
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | goundam
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | asau
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | iskateley
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 1 | cajamarca
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | ahipara
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | sirsi
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | tougue
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | alyangula
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | vanimo
# Processing Record 4 of Set 2 | kiama
# Processing Record 5 of Set 2 | russell
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | adelaide
# Processing Record 8 of Set 2 | waingapu
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | timberlake
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | honningsvag
# Processing Record 15 of Set 2 | calama
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | chitradurga
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | port-cartier
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | inta
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | kuldiga
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | dagumba-an
# Processing Record 27 of Set 2 | bol
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 2 | losone
# Processing Record 31 of Set 2 | kut chap
# Processing Record 32 of Set 2 | marion
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | san bartolome
# Processing Record 43 of Set 2 | dabat
# Processing Record 44 of Set 2 | manado
# Processing Record 45 of Set 2 | sioux lookout
# Processing Record 46 of Set 2 | pallapatti
# Processing Record 47 of Set 2 | trelew
# Processing Record 48 of Set 2 | fort nelson
# Processing Record 49 of Set 2 | boyuibe
# Processing Record 50 of Set 2 | sirnak
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | nhulunbuy
# Processing Record 3 of Set 3 | suoyarvi
# Processing Record 4 of Set 3 | grand gaube
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | senno
# Processing Record 7 of Set 3 | pokhara
# Processing Record 8 of Set 3 | belyy yar
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | paka
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | elko
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | fukuma
# Processing Record 17 of Set 3 | port blair
# Processing Record 18 of Set 3 | okhotsk
# Processing Record 19 of Set 3 | manavalakurichi
# Processing Record 20 of Set 3 | karpathos
# Processing Record 21 of Set 3 | casa nova
# Processing Record 22 of Set 3 | la primavera
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | linqiong
# Processing Record 25 of Set 3 | beringovskiy
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | siguiri
# Processing Record 28 of Set 3 | mount pleasant
# Processing Record 29 of Set 3 | san patricio
# Processing Record 30 of Set 3 | mahajanga
# Processing Record 31 of Set 3 | alto araguaia
# Processing Record 32 of Set 3 | acapulco
# Processing Record 33 of Set 3 | aix-les-bains
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | berlevag
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | la ronge
# Processing Record 40 of Set 3 | houma
# Processing Record 41 of Set 3 | mangrol
# Processing Record 42 of Set 3 | urumqi
# Processing Record 43 of Set 3 | hualmay
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | buin
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | umea
# Processing Record 49 of Set 3 | dingle
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | sao felix do xingu
# Processing Record 4 of Set 4 | dickinson
# Processing Record 5 of Set 4 | bocas del toro
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | vila do maio
# Processing Record 8 of Set 4 | corrente
# Processing Record 9 of Set 4 | koulikoro
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | omboue
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | san juan
# Processing Record 19 of Set 4 | luwingu
# Processing Record 20 of Set 4 | tete
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | tateyama
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | krasnyy yar
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | bonavista
# Processing Record 27 of Set 4 | coihaique
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | larion
# City not found. Skipping...
# Processing Record 32 of Set 4 | san quintin
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | santa rosa
# Processing Record 35 of Set 4 | mandan
# Processing Record 36 of Set 4 | khasan
# Processing Record 37 of Set 4 | andenes
# Processing Record 38 of Set 4 | port elizabeth
# Processing Record 39 of Set 4 | lakes entrance
# Processing Record 40 of Set 4 | nexo
# Processing Record 41 of Set 4 | caravelas
# Processing Record 42 of Set 4 | linares
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | babstovo
# Processing Record 46 of Set 4 | jumla
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | nador
# Processing Record 49 of Set 4 | camacha
# Processing Record 50 of Set 4 | kidal
# Processing Record 1 of Set 5 | tanete
# Processing Record 2 of Set 5 | iberia
# Processing Record 3 of Set 5 | lenger
# Processing Record 4 of Set 5 | kenitra
# Processing Record 5 of Set 5 | eydhafushi
# Processing Record 6 of Set 5 | igrim
# Processing Record 7 of Set 5 | monrovia
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | khair
# Processing Record 10 of Set 5 | egvekinot
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | fortuna
# Processing Record 13 of Set 5 | yuci
# Processing Record 14 of Set 5 | okha
# Processing Record 15 of Set 5 | coolum beach
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | ambilobe
# Processing Record 18 of Set 5 | queimadas
# Processing Record 19 of Set 5 | maragogi
# Processing Record 20 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 5 | oneonta
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | muros
# Processing Record 25 of Set 5 | naryan-mar
# Processing Record 26 of Set 5 | champerico
# Processing Record 27 of Set 5 | harsud
# Processing Record 28 of Set 5 | esperance
# Processing Record 29 of Set 5 | qasigiannguit
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | okato
# Processing Record 32 of Set 5 | pitimbu
# Processing Record 33 of Set 5 | lazaro cardenas
# Processing Record 34 of Set 5 | bahir dar
# Processing Record 35 of Set 5 | inndyr
# Processing Record 36 of Set 5 | pahalgam
# Processing Record 37 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 5 | astana
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | maua
# Processing Record 41 of Set 5 | ramsar
# Processing Record 42 of Set 5 | miraflores
# Processing Record 43 of Set 5 | mindelo
# Processing Record 44 of Set 5 | nikolsk
# Processing Record 45 of Set 5 | haines junction
# Processing Record 46 of Set 5 | marystown
# Processing Record 47 of Set 5 | vilcun
# Processing Record 48 of Set 5 | imeni zhelyabova
# Processing Record 49 of Set 5 | muana
# Processing Record 50 of Set 5 | jalu
# Processing Record 1 of Set 6 | kenai
# Processing Record 2 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | hagersville
# Processing Record 5 of Set 6 | nadym
# Processing Record 6 of Set 6 | saint-philippe
# Processing Record 7 of Set 6 | slonim
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | paldiski
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | luanda
# Processing Record 13 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 6 | abha
# Processing Record 15 of Set 6 | bilibino
# Processing Record 16 of Set 6 | iranshahr
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | batemans bay
# Processing Record 19 of Set 6 | charters towers
# Processing Record 20 of Set 6 | roma
# Processing Record 21 of Set 6 | wanning
# Processing Record 22 of Set 6 | grenfell
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | burica
# City not found. Skipping...
# Processing Record 25 of Set 6 | ordu
# Processing Record 26 of Set 6 | nerang
# Processing Record 27 of Set 6 | shelburne
# Processing Record 28 of Set 6 | hamilton
# Processing Record 29 of Set 6 | chokurdakh
# Processing Record 30 of Set 6 | balakliya
# Processing Record 31 of Set 6 | walvis bay
# Processing Record 32 of Set 6 | kintinku
# Processing Record 33 of Set 6 | lorengau
# Processing Record 34 of Set 6 | atikokan
# Processing Record 35 of Set 6 | lukovetskiy
# Processing Record 36 of Set 6 | brigantine
# Processing Record 37 of Set 6 | flinders
# Processing Record 38 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 6 | coahuayana
# Processing Record 40 of Set 6 | oriximina
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | makakilo city
# Processing Record 43 of Set 6 | saint-augustin
# Processing Record 44 of Set 6 | powell river
# Processing Record 45 of Set 6 | gazanjyk
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | lyngdal
# Processing Record 48 of Set 6 | kabinda
# Processing Record 49 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 6 | eyl
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | tecoanapa
# Processing Record 3 of Set 7 | necochea
# Processing Record 4 of Set 7 | hokitika
# Processing Record 5 of Set 7 | tambo
# Processing Record 6 of Set 7 | tubmanburg
# Processing Record 7 of Set 7 | los llanos de aridane
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | voskresenskoye
# Processing Record 10 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 7 | murray bridge
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | altay
# Processing Record 14 of Set 7 | semnan
# Processing Record 15 of Set 7 | seoul
# Processing Record 16 of Set 7 | vanavara
# Processing Record 17 of Set 7 | serebryansk
# Processing Record 18 of Set 7 | khilok
# Processing Record 19 of Set 7 | french harbor
# Processing Record 20 of Set 7 | severo-yeniseyskiy
# Processing Record 21 of Set 7 | krasnyy
# Processing Record 22 of Set 7 | mezen
# Processing Record 23 of Set 7 | cherskiy
# Processing Record 24 of Set 7 | upernavik
# Processing Record 25 of Set 7 | san carlos de bariloche
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | meulaboh
# Processing Record 28 of Set 7 | canico
# Processing Record 29 of Set 7 | redcar
# Processing Record 30 of Set 7 | srednekolymsk
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | gornopravdinsk
# Processing Record 33 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 7 | mirina
# City not found. Skipping...
# Processing Record 35 of Set 7 | anadyr
# Processing Record 36 of Set 7 | cockburn town
# Processing Record 37 of Set 7 | cabra
# Processing Record 38 of Set 7 | kuroishi
# Processing Record 39 of Set 7 | qobustan
# Processing Record 40 of Set 7 | inverness
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | obregon
# Processing Record 44 of Set 7 | guerrero negro
# Processing Record 45 of Set 7 | namatanai
# Processing Record 46 of Set 7 | bulata
# Processing Record 47 of Set 7 | suntar
# Processing Record 48 of Set 7 | mana
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | praia da vitoria
# Processing Record 1 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 8 | krasnoyarka
# Processing Record 3 of Set 8 | comodoro rivadavia
# Processing Record 4 of Set 8 | riyadh
# Processing Record 5 of Set 8 | sorland
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | bambous virieux
# Processing Record 8 of Set 8 | solenzo
# Processing Record 9 of Set 8 | muncar
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | ayan
# Processing Record 12 of Set 8 | tres arroyos
# Processing Record 13 of Set 8 | shawinigan
# Processing Record 14 of Set 8 | komsomolskiy
# Processing Record 15 of Set 8 | bairiki
# Processing Record 16 of Set 8 | pisco
# Processing Record 17 of Set 8 | chuchkovo
# Processing Record 18 of Set 8 | ukiah
# Processing Record 19 of Set 8 | ostersund
# Processing Record 20 of Set 8 | elk city
# Processing Record 21 of Set 8 | keflavik
# Processing Record 22 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 8 | sobolevo
# Processing Record 25 of Set 8 | ocampo
# Processing Record 26 of Set 8 | jamai
# Processing Record 27 of Set 8 | hailey
# Processing Record 28 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | nola
# Processing Record 30 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 8 | ternate
# Processing Record 33 of Set 8 | bubaque
# Processing Record 34 of Set 8 | tessalit
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | leh
# Processing Record 37 of Set 8 | abu zabad
# Processing Record 38 of Set 8 | lompoc
# Processing Record 39 of Set 8 | dakar
# Processing Record 40 of Set 8 | whitehorse
# Processing Record 41 of Set 8 | ndioum
# Processing Record 42 of Set 8 | millington
# Processing Record 43 of Set 8 | ballina
# Processing Record 44 of Set 8 | pusztaszabolcs
# Processing Record 45 of Set 8 | skjervoy
# Processing Record 46 of Set 8 | mutoko
# Processing Record 47 of Set 8 | mentougou
# Processing Record 48 of Set 8 | carballo
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | nykoping
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | mandalgovi
# Processing Record 5 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 9 | rio gallegos
# Processing Record 7 of Set 9 | qaqortoq
# Processing Record 8 of Set 9 | lebu
# Processing Record 9 of Set 9 | samana
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | ugoofaaru
# Processing Record 12 of Set 9 | basco
# Processing Record 13 of Set 9 | birao
# Processing Record 14 of Set 9 | barcelos
# Processing Record 15 of Set 9 | paragominas
# Processing Record 16 of Set 9 | teguldet
# Processing Record 17 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 9 | te anau
# Processing Record 19 of Set 9 | cunduacan
# Processing Record 20 of Set 9 | altona
# Processing Record 21 of Set 9 | morgan city
# Processing Record 22 of Set 9 | zhezkazgan
# Processing Record 23 of Set 9 | upata
# Processing Record 24 of Set 9 | chumikan
# Processing Record 25 of Set 9 | new richmond
# Processing Record 26 of Set 9 | aykhal
# Processing Record 27 of Set 9 | daru
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | candolim
# Processing Record 30 of Set 9 | asyut
# Processing Record 31 of Set 9 | isla mujeres
# Processing Record 32 of Set 9 | moranbah
# Processing Record 33 of Set 9 | vardo
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | brae
# Processing Record 36 of Set 9 | caraballeda
# Processing Record 37 of Set 9 | mountain home
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 9 | banda aceh
# Processing Record 41 of Set 9 | gashua
# Processing Record 42 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 43 of Set 9 | porteirinha
# Processing Record 44 of Set 9 | isangel
# Processing Record 45 of Set 9 | solnechnyy
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | muroto
# Processing Record 49 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 50 of Set 9 | huambo
# Processing Record 1 of Set 10 | baykit
# Processing Record 2 of Set 10 | eureka
# Processing Record 3 of Set 10 | myshkin
# Processing Record 4 of Set 10 | crestview
# Processing Record 5 of Set 10 | diego de almagro
# Processing Record 6 of Set 10 | areosa
# Processing Record 7 of Set 10 | kishtwar
# Processing Record 8 of Set 10 | marsh harbour
# Processing Record 9 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 10 | irtyshskiy
# Processing Record 11 of Set 10 | markova
# Processing Record 12 of Set 10 | baruun-urt
# Processing Record 13 of Set 10 | rajapur
# Processing Record 14 of Set 10 | mangai
# Processing Record 15 of Set 10 | sotik
# Processing Record 16 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 10 | nantucket
# Processing Record 18 of Set 10 | vilhena
# Processing Record 19 of Set 10 | tieli
# Processing Record 20 of Set 10 | santa marta
# Processing Record 21 of Set 10 | talipan
# Processing Record 22 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 10 | puerto narino
# Processing Record 24 of Set 10 | the valley
# Processing Record 25 of Set 10 | kruisfontein
# Processing Record 26 of Set 10 | garchitorena
# Processing Record 27 of Set 10 | ixtapa
# Processing Record 28 of Set 10 | xichang
# Processing Record 29 of Set 10 | lamu
# Processing Record 30 of Set 10 | cairns
# Processing Record 31 of Set 10 | maningrida
# Processing Record 32 of Set 10 | algiers
# Processing Record 33 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 10 | kashi
# Processing Record 35 of Set 10 | codrington
# Processing Record 36 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 10 | ammapettai
# Processing Record 38 of Set 10 | hare bay
# Processing Record 39 of Set 10 | migori
# Processing Record 40 of Set 10 | mae hong son
# Processing Record 41 of Set 10 | port lincoln
# Processing Record 42 of Set 10 | mawlaik
# Processing Record 43 of Set 10 | preobrazheniye
# Processing Record 44 of Set 10 | ishigaki
# Processing Record 45 of Set 10 | porto novo
# Processing Record 46 of Set 10 | bikramganj
# Processing Record 47 of Set 10 | marsa matruh
# Processing Record 48 of Set 10 | denpasar
# Processing Record 49 of Set 10 | vila
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | olga
# Processing Record 2 of Set 11 | pangnirtung
# Processing Record 3 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 11 | flin flon
# Processing Record 5 of Set 11 | sasebo
# Processing Record 6 of Set 11 | arman
# Processing Record 7 of Set 11 | hasaki
# Processing Record 8 of Set 11 | gigmoto
# Processing Record 9 of Set 11 | samarai
# Processing Record 10 of Set 11 | koungou
# Processing Record 11 of Set 11 | venado tuerto
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | swellendam
# Processing Record 14 of Set 11 | lahaina
# Processing Record 15 of Set 11 | burlington
# Processing Record 16 of Set 11 | aketi
# Processing Record 17 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 11 | yar-sale
# Processing Record 19 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 11 | houston
# Processing Record 21 of Set 11 | storforshei
# Processing Record 22 of Set 11 | puerto del rosario
# Processing Record 23 of Set 11 | bhandaria
# Processing Record 24 of Set 11 | pudozh
# Processing Record 25 of Set 11 | shingu
# Processing Record 26 of Set 11 | chernyshevskiy
# Processing Record 27 of Set 11 | sambava
# Processing Record 28 of Set 11 | kalabo
# Processing Record 29 of Set 11 | banyo
# Processing Record 30 of Set 11 | roald
# Processing Record 31 of Set 11 | itoman
# Processing Record 32 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 11 | korla
# Processing Record 34 of Set 11 | georgetown
# Processing Record 35 of Set 11 | manokwari
# Processing Record 36 of Set 11 | el cocuy
# Processing Record 37 of Set 11 | general roca
# Processing Record 38 of Set 11 | los rastrojos
# Processing Record 39 of Set 11 | dudinka
# Processing Record 40 of Set 11 | paoua
# Processing Record 41 of Set 11 | prado
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | toul
# Processing Record 44 of Set 11 | aras
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | jining
# Processing Record 47 of Set 11 | antigonish
# Processing Record 48 of Set 11 | dundee
# Processing Record 49 of Set 11 | royan
# Processing Record 50 of Set 11 | yefimovskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | babu
# Processing Record 2 of Set 12 | prusanky
# Processing Record 3 of Set 12 | santo amaro das brotas
# Processing Record 4 of Set 12 | mayor pablo lagerenza
# Processing Record 5 of Set 12 | bingerville
# Processing Record 6 of Set 12 | northam
# Processing Record 7 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | havre-saint-pierre
# Processing Record 9 of Set 12 | ziarat
# Processing Record 10 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 12 | krasnoselkup
# Processing Record 12 of Set 12 | mbour
# Processing Record 13 of Set 12 | jinka
# Processing Record 14 of Set 12 | camopi
# Processing Record 15 of Set 12 | miles city
# Processing Record 16 of Set 12 | kabo
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | burgeo
# Processing Record 19 of Set 12 | danielskuil
# Processing Record 20 of Set 12 | cayenne
# Processing Record 21 of Set 12 | el reno
# Processing Record 22 of Set 12 | mackay
# Processing Record 23 of Set 12 | pilot butte
# Processing Record 24 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 12 | aquiraz
# Processing Record 26 of Set 12 | khorol
# Processing Record 27 of Set 12 | yantarnyy
# Processing Record 28 of Set 12 | surt
# Processing Record 29 of Set 12 | terrace
# Processing Record 30 of Set 12 | long
# Processing Record 31 of Set 12 | bilma
# Processing Record 32 of Set 12 | shimoda
# Processing Record 33 of Set 12 | sarakhs
# Processing Record 34 of Set 12 | balikpapan
# Processing Record 35 of Set 12 | ulkan
# Processing Record 36 of Set 12 | atlantic city
# Processing Record 37 of Set 12 | buraydah
# Processing Record 38 of Set 12 | pitkyaranta
# Processing Record 39 of Set 12 | fare
# Processing Record 40 of Set 12 | pandan
# Processing Record 41 of Set 12 | beidao
# Processing Record 42 of Set 12 | mbini
# Processing Record 43 of Set 12 | hirara
# Processing Record 44 of Set 12 | kalmunai
# Processing Record 45 of Set 12 | miquelon
# Processing Record 46 of Set 12 | hingatungan
# Processing Record 47 of Set 12 | manaus
# Processing Record 48 of Set 12 | vila franca do campo
# Processing Record 49 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 12 | tongliao
# Processing Record 1 of Set 13 | sosnovo-ozerskoye
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | andilamena
# Processing Record 4 of Set 13 | erenhot
# Processing Record 5 of Set 13 | gari
# Processing Record 6 of Set 13 | certesti
# Processing Record 7 of Set 13 | chaykovskaya
# Processing Record 8 of Set 13 | saint-louis
# Processing Record 9 of Set 13 | mamakan
# Processing Record 10 of Set 13 | poum
# Processing Record 11 of Set 13 | tefe
# Processing Record 12 of Set 13 | presidencia roque saenz pena
# Processing Record 13 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 14 of Set 13 | gamba
# Processing Record 15 of Set 13 | sakaiminato
# Processing Record 16 of Set 13 | naranjal
# Processing Record 17 of Set 13 | san andres
# Processing Record 18 of Set 13 | antofagasta
# Processing Record 19 of Set 13 | krasnaya gora
# Processing Record 20 of Set 13 | luganville
# Processing Record 21 of Set 13 | sao gabriel da cachoeira
# Processing Record 22 of Set 13 | galveston
# Processing Record 23 of Set 13 | cabedelo
# Processing Record 24 of Set 13 | biak
# Processing Record 25 of Set 13 | matale
# Processing Record 26 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 13 | cambridge
# Processing Record 28 of Set 13 | abalak
# Processing Record 29 of Set 13 | goure
# Processing Record 30 of Set 13 | razole
# Processing Record 31 of Set 13 | davila
# Processing Record 32 of Set 13 | kaeo
# Processing Record 33 of Set 13 | pareora
# Processing Record 34 of Set 13 | buala
# Processing Record 35 of Set 13 | bexhill
# Processing Record 36 of Set 13 | pueblo nuevo
# Processing Record 37 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 13 | kamaishi
# Processing Record 40 of Set 13 | saint-claude
# Processing Record 41 of Set 13 | toba tek singh
# Processing Record 42 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 13 | svetlyy
# Processing Record 44 of Set 13 | teknaf
# Processing Record 45 of Set 13 | ardakan
# Processing Record 46 of Set 13 | nome
# Processing Record 47 of Set 13 | teya
# Processing Record 48 of Set 13 | gladstone
# Processing Record 49 of Set 13 | raudeberg
# Processing Record 50 of Set 13 | naruto
# Processing Record 1 of Set 14 | taltal
# Processing Record 2 of Set 14 | ust-maya
# Processing Record 3 of Set 14 | emba
# Processing Record 4 of Set 14 | belmonte
# Processing Record 5 of Set 14 | batagay-alyta
# Processing Record 6 of Set 14 | le port
# Processing Record 7 of Set 14 | zatoka
# Processing Record 8 of Set 14 | dong hoi
# Processing Record 9 of Set 14 | ponta pora
# Processing Record 10 of Set 14 | parkersburg
# Processing Record 11 of Set 14 | southbridge
# Processing Record 12 of Set 14 | ivanava
# Processing Record 13 of Set 14 | tabou
# Processing Record 14 of Set 14 | cloquet
# Processing Record 15 of Set 14 | peniche
# Processing Record 16 of Set 14 | parrita
# Processing Record 17 of Set 14 | macas
# Processing Record 18 of Set 14 | margate
# Processing Record 19 of Set 14 | nicolas bravo
# Processing Record 20 of Set 14 | kavieng
# Processing Record 21 of Set 14 | rancho palos verdes
# Processing Record 22 of Set 14 | general pico
# Processing Record 23 of Set 14 | valdagno
# Processing Record 24 of Set 14 | verkhoyansk
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | innisfail
# Processing Record 27 of Set 14 | warmbad
# Processing Record 28 of Set 14 | nchelenge
# Processing Record 29 of Set 14 | naze
# Processing Record 30 of Set 14 | la romana
# Processing Record 31 of Set 14 | avera
# Processing Record 32 of Set 14 | aromashevo
# Processing Record 33 of Set 14 | san fernando
# Processing Record 34 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 14 | kysyl-syr
# Processing Record 36 of Set 14 | sukhumi
# Processing Record 37 of Set 14 | deputatskiy
# Processing Record 38 of Set 14 | norsup
# Processing Record 39 of Set 14 | kahama
# Processing Record 40 of Set 14 | orotukan
# Processing Record 41 of Set 14 | kununurra
# Processing Record 42 of Set 14 | kamphaeng phet
# Processing Record 43 of Set 14 | boueni
# Processing Record 44 of Set 14 | kharan
# Processing Record 45 of Set 14 | ust-omchug
# Processing Record 46 of Set 14 | skeldon
# Processing Record 47 of Set 14 | yarmouth
# Processing Record 48 of Set 14 | inuvik
# Processing Record 49 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 14 | westport
# Processing Record 1 of Set 15 | terrace bay
# Processing Record 2 of Set 15 | morro bay
# Processing Record 3 of Set 15 | abu samrah
# Processing Record 4 of Set 15 | beloha
# Processing Record 5 of Set 15 | homer
# Processing Record 6 of Set 15 | juniyah
# City not found. Skipping...
# Processing Record 7 of Set 15 | inongo
# Processing Record 8 of Set 15 | grand-santi
# Processing Record 9 of Set 15 | sola
# Processing Record 10 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 15 | glubokoe
# City not found. Skipping...
# Processing Record 12 of Set 15 | pacasmayo
# Processing Record 13 of Set 15 | khoy
# Processing Record 14 of Set 15 | huai mek
# Processing Record 15 of Set 15 | male
# Processing Record 16 of Set 15 | atasu
# Processing Record 17 of Set 15 | syamzha
# Processing Record 18 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 15 | kasongo
# Processing Record 20 of Set 15 | barra
# Processing Record 21 of Set 15 | perigueux
# Processing Record 22 of Set 15 | filadelfia
# Processing Record 23 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 24 of Set 15 | atamanovka
# Processing Record 25 of Set 15 | manuk mangkaw
# Processing Record 26 of Set 15 | puerto colombia
# Processing Record 27 of Set 15 | gbarnga
# Processing Record 28 of Set 15 | altagracia de orituco
# Processing Record 29 of Set 15 | sorong
# Processing Record 30 of Set 15 | teguise
# Processing Record 31 of Set 15 | farkhor
# Processing Record 32 of Set 15 | concarneau
# Processing Record 33 of Set 15 | mangochi
# Processing Record 34 of Set 15 | tiganasi
# Processing Record 35 of Set 15 | adrar
# Processing Record 36 of Set 15 | hutchinson
# Processing Record 37 of Set 15 | marawi
# Processing Record 38 of Set 15 | fort-shevchenko
# Processing Record 39 of Set 15 | sooke
# Processing Record 40 of Set 15 | bundaberg
# Processing Record 41 of Set 15 | sarh
# Processing Record 42 of Set 15 | pacific grove
# Processing Record 43 of Set 15 | lexington park
# Processing Record 44 of Set 15 | myitkyina
# Processing Record 45 of Set 15 | nisko
# Processing Record 46 of Set 15 | oktyabrskoye
# Processing Record 47 of Set 15 | santa isabel
# Processing Record 48 of Set 15 | plettenberg bay
# Processing Record 49 of Set 15 | longuenesse
# Processing Record 50 of Set 15 | quang ngai
# Processing Record 1 of Set 16 | la ligua
# Processing Record 2 of Set 16 | placido de castro
# Processing Record 3 of Set 16 | vredendal
# Processing Record 4 of Set 16 | lindi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Hobart',
#   'Lat': -42.8794,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 147.3294,
#   'Max Temp': 52,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:46:29'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'Lng': -68.3,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Date': '2021-04-19 20:41:40'},
#  {'City': 'Karasburg',
#   'Lat': -28.0167,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 18.75,
#   'Max Temp': 72.23,
#   'Humidity': 24,
#   'Cloudiness': 6,
#   'Wind Speed': 11.5,
#   'Country': 'NA',
#   'Date': '2021-04-19 20:47:56'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 18.4232,
#   'Max Temp': 63,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:46:12'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -156.7887,
#   'Max Temp': 24.8,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Date': '2021-04-19 20:41:19'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -78.1522,
#   'Max Temp': 73.4,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 11.07,
#   'Country': 'PE',
#   'Date': '2021-04-19 20:47:56'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -69.3632,
#   'Max Temp': 6.69,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:46:14'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -54.3333,
#   'Max Temp': 63.05,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Country': 'UY',
#   'Date': '2021-04-19 20:47:57'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 26.891,
#   'Max Temp': 64.33,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 11.61,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:46:31'},
#  {'City': 'Hinton',
#   'Lat': 53.4001,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -117.5857,
#   'Max Temp': 46.4,
#   'Humidity': 27,
#   'Cloudiness': 5,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:47:57'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -134.9692,
#   'Max Temp': 77.99,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 10.31,
#   'Country': 'PF',
#   'Date': '2021-04-19 20:46:11'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -133.0374,
#   'Max Temp': 24.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:46:17'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 20.0403,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:46:29'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -126.8329,
#   'Max Temp': 48.2,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:47:06'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -49.6678,
#   'Max Temp': 32.32,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:47:58'},
#  {'City': 'Samfya',
#   'Lat': -11.3649,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 29.5565,
#   'Max Temp': 65.97,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Country': 'ZM',
#   'Date': '2021-04-19 20:47:58'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -73.9662,
#   'Max Temp': 59,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'US',
#   'Date': '2021-04-19 20:46:12'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 27.8492,
#   'Max Temp': 37.4,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'NO',
#   'Date': '2021-04-19 20:46:56'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 97.2,
#   'Max Temp': 51.71,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'CN',
#   'Date': '2021-04-19 20:47:58'},
#  {'City': 'Dzaoudzi',
#   'Lat': -12.7887,
#   'Weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'Lng': 45.2699,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'YT',
#   'Date': '2021-04-19 20:47:59'},
#  {'City': 'Luangwa',
#   'Lat': -15.6167,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 30.4167,
#   'Max Temp': 64.4,
#   'Humidity': 81,
#   'Cloudiness': 17,
#   'Wind Speed': 0.72,
#   'Country': 'ZM',
#   'Date': '2021-04-19 20:47:59'},
#  {'City': 'Marabba',
#   'Lat': 12.35,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 32.1833,
#   'Max Temp': 93.07,
#   'Humidity': 10,
#   'Cloudiness': 97,
#   'Wind Speed': 6.78,
#   'Country': 'SD',
#   'Date': '2021-04-19 20:47:59'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -149.15,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'PF',
#   'Date': '2021-04-19 20:41:40'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -70.9167,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'CL',
#   'Date': '2021-04-19 20:44:24'},
#  {'City': 'Bara',
#   'Lat': 10.3744,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 10.7288,
#   'Max Temp': 88.16,
#   'Humidity': 23,
#   'Cloudiness': 81,
#   'Wind Speed': 5.5,
#   'Country': 'NG',
#   'Date': '2021-04-19 20:48:00'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -156.47,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-04-19 20:43:56'},
#  {'City': 'Goundam',
#   'Lat': 16.4145,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': -3.6708,
#   'Max Temp': 89.82,
#   'Humidity': 10,
#   'Cloudiness': 20,
#   'Wind Speed': 10.8,
#   'Country': 'ML',
#   'Date': '2021-04-19 20:48:00'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': -139.0333,
#   'Max Temp': 79.72,
#   'Humidity': 79,
#   'Cloudiness': 21,
#   'Wind Speed': 18.95,
#   'Country': 'PF',
#   'Date': '2021-04-19 20:46:51'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 26.4,
#   'Max Temp': 45,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'RO',
#   'Date': '2021-04-19 20:47:51'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 17.9442,
#   'Max Temp': 68,
#   'Humidity': 56,
#   'Cloudiness': 9,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:46:10'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 168.3333,
#   'Max Temp': 54,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-04-19 20:42:45'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 53.1512,
#   'Max Temp': 27.55,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 12.06,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:01'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 139.5,
#   'Max Temp': 69.8,
#   'Humidity': 32,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:46:41'},
#  {'City': 'Cajamarca',
#   'Lat': -7.1638,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': -78.5003,
#   'Max Temp': 60.53,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 3.96,
#   'Country': 'PE',
#   'Date': '2021-04-19 20:44:02'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 30.7861,
#   'Max Temp': 41,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:42:46'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': 173.1667,
#   'Max Temp': 63.54,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 19.39,
#   'Country': 'NZ',
#   'Date': '2021-04-19 20:42:47'},
#  {'City': 'Sirsi',
#   'Lat': 14.6167,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 74.85,
#   'Max Temp': 72.64,
#   'Humidity': 93,
#   'Cloudiness': 67,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:48:02'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 19.2345,
#   'Max Temp': 61,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 11.01,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:43:08'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 102.2655,
#   'Max Temp': 75.4,
#   'Humidity': 88,
#   'Cloudiness': 55,
#   'Wind Speed': 3.47,
#   'Country': 'ID',
#   'Date': '2021-04-19 20:48:02'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': -27.9833,
#   'Max Temp': 62.19,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 6.71,
#   'Country': 'PT',
#   'Date': '2021-04-19 20:47:22'},
#  {'City': 'Tougue',
#   'Lat': 11.4667,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': -11.6,
#   'Max Temp': 83.12,
#   'Humidity': 38,
#   'Cloudiness': 92,
#   'Wind Speed': 4.34,
#   'Country': 'GN',
#   'Date': '2021-04-19 20:48:03'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': -35.4608,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:46:48'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -22.4338,
#   'Max Temp': 32,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'IS',
#   'Date': '2021-04-19 20:48:03'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 136.4192,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.5,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:48:03'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': -173.3,
#   'Max Temp': 30.2,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:25'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 115.3333,
#   'Max Temp': 53.01,
#   'Humidity': 98,
#   'Cloudiness': 77,
#   'Wind Speed': 7.78,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:41:41'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 15.1594,
#   'Max Temp': 70.14,
#   'Humidity': 62,
#   'Cloudiness': 68,
#   'Wind Speed': 10.69,
#   'Country': 'NA',
#   'Date': '2021-04-19 20:46:33'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': -17.1,
#   'Max Temp': 62.01,
#   'Humidity': 69,
#   'Cloudiness': 28,
#   'Wind Speed': 1.01,
#   'Country': 'PT',
#   'Date': '2021-04-19 20:47:47'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': 141.3028,
#   'Max Temp': 75.45,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 3.89,
#   'Country': 'PG',
#   'Date': '2021-04-19 20:48:04'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 150.8667,
#   'Max Temp': 53.01,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:48:04'},
#  {'City': 'Russell',
#   'Lat': 32.3502,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -85.1999,
#   'Max Temp': 73.4,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 6.67,
#   'Country': 'US',
#   'Date': '2021-04-19 20:48:05'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': 114.0833,
#   'Max Temp': -15.93,
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:18'},
#  {'City': 'Adelaide',
#   'Lat': -34.9333,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 138.6,
#   'Max Temp': 54,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:45:02'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 120.2641,
#   'Max Temp': 72.7,
#   'Humidity': 77,
#   'Cloudiness': 21,
#   'Wind Speed': 5.17,
#   'Country': 'ID',
#   'Date': '2021-04-19 20:47:13'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -159.319,
#   'Max Temp': 79,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-04-19 20:46:33'},
#  {'City': 'Timberlake',
#   'Lat': 37.3207,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -79.2575,
#   'Max Temp': 69.01,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-04-19 20:48:05'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -45.2371,
#   'Max Temp': 33.13,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:46:10'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': -42.0278,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:06'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 147.0587,
#   'Max Temp': 52,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:46:23'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 25.9704,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'NO',
#   'Date': '2021-04-19 20:48:06'},
#  {'City': 'Calama',
#   'Lat': -22.4667,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -68.9333,
#   'Max Temp': 71.6,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Country': 'CL',
#   'Date': '2021-04-19 20:48:06'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': 128.8694,
#   'Max Temp': -6.41,
#   'Humidity': 99,
#   'Cloudiness': 86,
#   'Wind Speed': 3.04,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:36'},
#  {'City': 'Chitradurga',
#   'Lat': 14.2333,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 76.4,
#   'Max Temp': 76.05,
#   'Humidity': 74,
#   'Cloudiness': 61,
#   'Wind Speed': 13.31,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:46:19'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': 102.5,
#   'Max Temp': -20.24,
#   'Humidity': 100,
#   'Cloudiness': 32,
#   'Wind Speed': 2.95,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:41:42'},
#  {'City': 'Port-Cartier',
#   'Lat': 50.0334,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -66.8654,
#   'Max Temp': 48.99,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:48:07'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -79.2353,
#   'Max Temp': 61,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-04-19 20:45:20'},
#  {'City': 'Inta',
#   'Lat': 66.0317,
#   'Weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'Lng': 60.1659,
#   'Max Temp': 31.17,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 19.95,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:07'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 169.8464,
#   'Max Temp': 50,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'NZ',
#   'Date': '2021-04-19 20:47:24'},
#  {'City': 'Kuldiga',
#   'Lat': 56.974,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 21.9572,
#   'Max Temp': 48.2,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'LV',
#   'Date': '2021-04-19 20:46:59'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 114.1577,
#   'Max Temp': 72,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-04-19 20:46:58'},
#  {'City': 'Dagumba-An',
#   'Lat': 8.1531,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 124.5908,
#   'Max Temp': 73,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'PH',
#   'Date': '2021-04-19 20:48:08'},
#  {'City': 'Bol',
#   'Lat': 13.4586,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 14.7147,
#   'Max Temp': 83.64,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 9.93,
#   'Country': 'TD',
#   'Date': '2021-04-19 20:48:08'},
#  {'City': 'Losone',
#   'Lat': 46.1687,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 8.7593,
#   'Max Temp': 51.8,
#   'Humidity': 46,
#   'Cloudiness': 72,
#   'Wind Speed': 2.3,
#   'Country': 'CH',
#   'Date': '2021-04-19 20:48:09'},
#  {'City': 'Kut Chap',
#   'Lat': 17.4257,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 102.5669,
#   'Max Temp': 79,
#   'Humidity': 89,
#   'Cloudiness': 92,
#   'Wind Speed': 0.92,
#   'Country': 'TH',
#   'Date': '2021-04-19 20:48:09'},
#  {'City': 'Marion',
#   'Lat': 39.7684,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': -86.1555,
#   'Max Temp': 66,
#   'Humidity': 32,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2021-04-19 20:44:43'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -59.5167,
#   'Max Temp': 82.4,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Country': 'BB',
#   'Date': '2021-04-19 20:48:09'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': -175.2,
#   'Max Temp': 73.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'TO',
#   'Date': '2021-04-19 20:46:12'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'Lng': -152.4072,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Date': '2021-04-19 20:47:42'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 168.8643,
#   'Max Temp': 54,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-04-19 20:41:41'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 167.6833,
#   'Max Temp': 54,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-04-19 20:46:28'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': -39.9167,
#   'Max Temp': 77.25,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 5.57,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:10'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': 170.3133,
#   'Max Temp': 16.21,
#   'Humidity': 83,
#   'Cloudiness': 23,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:47:18'},
#  {'City': 'San Bartolome',
#   'Lat': 27.9248,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': -15.5733,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Country': 'ES',
#   'Date': '2021-04-19 20:48:11'},
#  {'City': 'Dabat',
#   'Lat': 12.9842,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 37.765,
#   'Max Temp': 61.9,
#   'Humidity': 38,
#   'Cloudiness': 92,
#   'Wind Speed': 5.14,
#   'Country': 'ET',
#   'Date': '2021-04-19 20:48:11'},
#  {'City': 'Manado',
#   'Lat': 1.487,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': 124.8455,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.64,
#   'Country': 'ID',
#   'Date': '2021-04-19 20:47:10'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -91.917,
#   'Max Temp': 33.8,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:48:12'},
#  {'City': 'Pallapatti',
#   'Lat': 11.6593,
#   'Weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10n'}],
#   'Lng': 78.1342,
#   'Max Temp': 80.8,
#   'Humidity': 64,
#   'Cloudiness': 81,
#   'Wind Speed': 3.49,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:48:12'},
#  {'City': 'Trelew',
#   'Lat': -43.249,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -65.3051,
#   'Max Temp': 85.24,
#   'Humidity': 20,
#   'Cloudiness': 11,
#   'Wind Speed': 16.31,
#   'Country': 'AR',
#   'Date': '2021-04-19 20:48:13'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -122.7002,
#   'Max Temp': 53.6,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:48:13'},
#  {'City': 'Boyuibe',
#   'Lat': -20.4167,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': -63.2833,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.52,
#   'Country': 'BO',
#   'Date': '2021-04-19 20:48:13'},
#  {'City': 'Sirnak',
#   'Lat': 37.5228,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 42.4594,
#   'Max Temp': 63.63,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Country': 'TR',
#   'Date': '2021-04-19 20:48:13'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.2333,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': 136.7667,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:48:14'},
#  {'City': 'Suoyarvi',
#   'Lat': 62.0833,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 32.35,
#   'Max Temp': 35.29,
#   'Humidity': 78,
#   'Cloudiness': 95,
#   'Wind Speed': 4.65,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:14'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': 57.6608,
#   'Max Temp': 75.99,
#   'Humidity': 87,
#   'Cloudiness': 23,
#   'Wind Speed': 1.99,
#   'Country': 'MU',
#   'Date': '2021-04-19 20:48:14'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -53.4616,
#   'Max Temp': 66.11,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'UY',
#   'Date': '2021-04-19 20:44:49'},
#  {'City': 'Senno',
#   'Lat': 59.5336,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 33.9167,
#   'Max Temp': 37.33,
#   'Humidity': 65,
#   'Cloudiness': 81,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:15'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 83.9833,
#   'Max Temp': 68.74,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 8.23,
#   'Country': 'NP',
#   'Date': '2021-04-19 20:47:37'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 91.3903,
#   'Max Temp': 23,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:15'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': -127.4199,
#   'Max Temp': 57.2,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:45:02'},
#  {'City': 'Paka',
#   'Lat': 4.6374,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 103.4368,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 6.91,
#   'Country': 'MY',
#   'Date': '2021-04-19 20:48:16'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -50.2056,
#   'Max Temp': 69.69,
#   'Humidity': 74,
#   'Cloudiness': 61,
#   'Wind Speed': 11.81,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:16'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -159.775,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'CK',
#   'Date': '2021-04-19 20:46:20'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': 140.3,
#   'Max Temp': 55.4,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'JP',
#   'Date': '2021-04-19 20:46:37'},
#  {'City': 'Elko',
#   'Lat': 41.0002,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -115.5012,
#   'Max Temp': 64.4,
#   'Humidity': 17,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Country': 'US',
#   'Date': '2021-04-19 20:45:02'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 57.5167,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.64,
#   'Country': 'MU',
#   'Date': '2021-04-19 20:48:16'},
#  {'City': 'Fukuma',
#   'Lat': 33.7667,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 130.4667,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2021-04-19 20:48:17'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 92.75,
#   'Max Temp': 80.98,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:47:26'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'Lng': 143.3,
#   'Max Temp': 32.65,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 27.65,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:17'},
#  {'City': 'Manavalakurichi',
#   'Lat': 8.1333,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#   'Lng': 77.3,
#   'Max Temp': 82.4,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:48:17'},
#  {'City': 'Karpathos',
#   'Lat': 35.507,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 27.2132,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 34,
#   'Wind Speed': 19.57,
#   'Country': 'GR',
#   'Date': '2021-04-19 20:48:18'},
#  {'City': 'Casa Nova',
#   'Lat': -9.4167,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': -41.1333,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:18'},
#  {'City': 'La Primavera',
#   'Lat': 5.4906,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -70.4092,
#   'Max Temp': 91.18,
#   'Humidity': 41,
#   'Cloudiness': 91,
#   'Wind Speed': 6.67,
#   'Country': 'CO',
#   'Date': '2021-04-19 20:48:18'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 100.3543,
#   'Max Temp': 76.44,
#   'Humidity': 87,
#   'Cloudiness': 38,
#   'Wind Speed': 3.89,
#   'Country': 'ID',
#   'Date': '2021-04-19 20:48:19'},
#  {'City': 'Linqiong',
#   'Lat': 30.4159,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 103.4609,
#   'Max Temp': 59,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.8,
#   'Country': 'CN',
#   'Date': '2021-04-19 20:48:19'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': 179.3167,
#   'Max Temp': 23.95,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 8.88,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:48:19'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': -90.3518,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'EC',
#   'Date': '2021-04-19 20:48:20'},
#  {'City': 'Siguiri',
#   'Lat': 11.6667,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': -9.5,
#   'Max Temp': 92.44,
#   'Humidity': 14,
#   'Cloudiness': 41,
#   'Wind Speed': 1.88,
#   'Country': 'GN',
#   'Date': '2021-04-19 20:48:20'},
#  {'City': 'Mount Pleasant',
#   'Lat': 32.7941,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -79.8626,
#   'Max Temp': 79,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2021-04-19 20:43:40'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -97.5169,
#   'Max Temp': 71.6,
#   'Humidity': 49,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-04-19 20:47:18'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 46.3167,
#   'Max Temp': 78.8,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'MG',
#   'Date': '2021-04-19 20:48:20'},
#  {'City': 'Alto Araguaia',
#   'Lat': -17.3147,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -53.2153,
#   'Max Temp': 73.94,
#   'Humidity': 66,
#   'Cloudiness': 77,
#   'Wind Speed': 2.93,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:21'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -99.8901,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'MX',
#   'Date': '2021-04-19 20:45:38'},
#  {'City': 'Aix-Les-Bains',
#   'Lat': 45.6834,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 5.9224,
#   'Max Temp': 50,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'FR',
#   'Date': '2021-04-19 20:48:21'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -109.9124,
#   'Max Temp': 84.2,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'MX',
#   'Date': '2021-04-19 20:40:42'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': -15.2082,
#   'Max Temp': 39.79,
#   'Humidity': 58,
#   'Cloudiness': 11,
#   'Wind Speed': 6.29,
#   'Country': 'IS',
#   'Date': '2021-04-19 20:46:52'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 29.0864,
#   'Max Temp': 41,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Date': '2021-04-19 20:48:22'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': -114.3525,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:44:55'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 88.3972,
#   'Max Temp': -13.13,
#   'Humidity': 96,
#   'Cloudiness': 59,
#   'Wind Speed': 3.15,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:59'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -105.2842,
#   'Max Temp': 35.6,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:48:23'},
#  {'City': 'Houma',
#   'Lat': 29.5958,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -90.7195,
#   'Max Temp': 72,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-04-19 20:48:23'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 70.1167,
#   'Max Temp': 79.52,
#   'Humidity': 82,
#   'Cloudiness': 93,
#   'Wind Speed': 11.18,
#   'Country': 'IN',
#   'Date': '2021-04-19 20:48:23'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 87.6005,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': '2021-04-19 20:48:24'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -77.6139,
#   'Max Temp': 72.46,
#   'Humidity': 73,
#   'Cloudiness': 74,
#   'Wind Speed': 10.85,
#   'Country': 'PE',
#   'Date': '2021-04-19 20:48:24'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 10.7002,
#   'Max Temp': 55.4,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'IT',
#   'Date': '2021-04-19 20:48:24'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 113.6333,
#   'Max Temp': 73.02,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 22.1,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:46:19'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -70.75,
#   'Max Temp': 71.6,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Date': '2021-04-19 20:48:25'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -155.09,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-04-19 20:42:26'},
#  {'City': 'Umea',
#   'Lat': 63.8284,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 20.2597,
#   'Max Temp': 36,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.19,
#   'Country': 'SE',
#   'Date': '2021-04-19 20:48:25'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'Lng': 122.6711,
#   'Max Temp': 76.42,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'PH',
#   'Date': '2021-04-19 20:48:25'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': -28.7,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'PT',
#   'Date': '2021-04-19 20:46:47'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -51.1,
#   'Max Temp': 19.4,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:47:29'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -57.5575,
#   'Max Temp': 75.2,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AR',
#   'Date': '2021-04-19 20:46:38'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -51.995,
#   'Max Temp': 75.52,
#   'Humidity': 95,
#   'Cloudiness': 68,
#   'Wind Speed': 0.87,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:26'},
#  {'City': 'Dickinson',
#   'Lat': 29.4608,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -95.0513,
#   'Max Temp': 73.99,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-04-19 20:48:26'},
#  {'City': 'Bocas Del Toro',
#   'Lat': 9.3333,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -82.25,
#   'Max Temp': 69.01,
#   'Humidity': 73,
#   'Cloudiness': 92,
#   'Wind Speed': 5.01,
#   'Country': 'PA',
#   'Date': '2021-04-19 20:48:26'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'Lng': -68.5145,
#   'Max Temp': 23,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:46:27'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': -23.2167,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'CV',
#   'Date': '2021-04-19 20:47:41'},
#  {'City': 'Corrente',
#   'Lat': -3.7367,
#   'Weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'Lng': -43.3394,
#   'Max Temp': 71.13,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:48:27'},
#  {'City': 'Koulikoro',
#   'Lat': 14,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': -7.75,
#   'Max Temp': 89.47,
#   'Humidity': 13,
#   'Cloudiness': 2,
#   'Wind Speed': 8.43,
#   'Country': 'ML',
#   'Date': '2021-04-19 20:48:27'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -46.05,
#   'Max Temp': 42.8,
#   'Humidity': 36,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:47:17'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'Lng': -50.0119,
#   'Max Temp': 59.4,
#   'Humidity': 87,
#   'Cloudiness': 25,
#   'Wind Speed': 4.79,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:46:34'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -113.5841,
#   'Max Temp': 80.01,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-04-19 20:46:08'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -37.6368,
#   'Max Temp': 26.6,
#   'Humidity': 68,
#   'Cloudiness': 3,
#   'Wind Speed': 9.22,
#   'Country': 'GL',
#   'Date': '2021-04-19 20:42:46'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': 9.2618,
#   'Max Temp': 78.66,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'GA',
#   'Date': '2021-04-19 20:48:28'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 178.4167,
#   'Max Temp': 18.7,
#   'Humidity': 79,
#   'Cloudiness': 3,
#   'Wind Speed': 2.44,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:50'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 80.5464,
#   'Max Temp': -5.4,
#   'Humidity': 97,
#   'Cloudiness': 12,
#   'Wind Speed': 7.49,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:46:24'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': 172.7902,
#   'Max Temp': 83.23,
#   'Humidity': 76,
#   'Cloudiness': 94,
#   'Wind Speed': 14,
#   'Country': 'KI',
#   'Date': '2021-04-19 20:46:21'},
#  {'City': 'San Juan',
#   'Lat': -31.5375,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -68.5364,
#   'Max Temp': 86.77,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 8.86,
#   'Country': 'AR',
#   'Date': '2021-04-19 20:48:29'},
#  {'City': 'Luwingu',
#   'Lat': -10.2621,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 29.9271,
#   'Max Temp': 61.63,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Country': 'ZM',
#   'Date': '2021-04-19 20:48:29'},
#  {'City': 'Tete',
#   'Lat': -16.1564,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': 33.5867,
#   'Max Temp': 69.8,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.81,
#   'Country': 'MZ',
#   'Date': '2021-04-19 20:48:29'},
#  {'City': 'Tateyama',
#   'Lat': 34.9833,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': 139.8667,
#   'Max Temp': 55.4,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'JP',
#   'Date': '2021-04-19 20:48:30'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'Lng': -24.4956,
#   'Max Temp': 73.89,
#   'Humidity': 74,
#   'Cloudiness': 38,
#   'Wind Speed': 13.67,
#   'Country': 'CV',
#   'Date': '2021-04-19 20:48:30'},
#  {'City': 'Krasnyy Yar',
#   'Lat': 46.5331,
# ...
#  {'City': 'Ust-Omchug',
#   'Lat': 61.15,
#   'Weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'Lng': 149.6333,
#   'Max Temp': 30.65,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.83,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:50:41'},
#  {'City': 'Skeldon',
#   'Lat': 5.8833,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -57.1333,
#   'Max Temp': 79.21,
#   'Humidity': 72,
#   'Cloudiness': 83,
#   'Wind Speed': 7.31,
#   'Country': 'GY',
#   'Date': '2021-04-19 20:50:42'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -70.2286,
#   'Max Temp': 60.01,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-04-19 20:50:42'},
#  {'City': 'Inuvik',
#   'Lat': 68.3499,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -133.7218,
#   'Max Temp': 44.6,
#   'Humidity': 42,
#   'Cloudiness': 98,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:46:57'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -73.3579,
#   'Max Temp': 61,
#   'Humidity': 41,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-04-19 20:43:57'},
#  {'City': 'Terrace Bay',
#   'Lat': 48.7834,
#   'Weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'Lng': -87.1,
#   'Max Temp': 24.8,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:50:43'},
#  {'City': 'Morro Bay',
#   'Lat': 35.3658,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': -120.8499,
#   'Max Temp': 81,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Date': '2021-04-19 20:50:43'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3029,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 37.1841,
#   'Max Temp': 79.07,
#   'Humidity': 31,
#   'Cloudiness': 99,
#   'Wind Speed': 8.43,
#   'Country': 'SY',
#   'Date': '2021-04-19 20:50:43'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 45.05,
#   'Max Temp': 68.13,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 13.4,
#   'Country': 'MG',
#   'Date': '2021-04-19 20:50:44'},
#  {'City': 'Homer',
#   'Lat': 59.6425,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': -151.5483,
#   'Max Temp': 53.6,
#   'Humidity': 47,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-04-19 20:50:44'},
#  {'City': 'Inongo',
#   'Lat': -1.95,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 18.2667,
#   'Max Temp': 73.44,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'CD',
#   'Date': '2021-04-19 20:50:44'},
#  {'City': 'Grand-Santi',
#   'Lat': 4.25,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -54.3833,
#   'Max Temp': 75.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'GF',
#   'Date': '2021-04-19 20:50:45'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': 167.55,
#   'Max Temp': 82.65,
#   'Humidity': 77,
#   'Cloudiness': 58,
#   'Wind Speed': 11.52,
#   'Country': 'VU',
#   'Date': '2021-04-19 20:50:45'},
#  {'City': 'Pacasmayo',
#   'Lat': -7.4006,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -79.5714,
#   'Max Temp': 72.88,
#   'Humidity': 72,
#   'Cloudiness': 83,
#   'Wind Speed': 15.52,
#   'Country': 'PE',
#   'Date': '2021-04-19 20:50:45'},
#  {'City': 'Khoy',
#   'Lat': 38.5504,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 44.9535,
#   'Max Temp': 66.81,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'IR',
#   'Date': '2021-04-19 20:50:46'},
#  {'City': 'Huai Mek',
#   'Lat': 16.5898,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 103.2355,
#   'Max Temp': 80.01,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 4.61,
#   'Country': 'TH',
#   'Date': '2021-04-19 20:50:46'},
#  {'City': 'Male',
#   'Lat': 4.1748,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 73.5089,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'MV',
#   'Date': '2021-04-19 20:50:46'},
#  {'City': 'Atasu',
#   'Lat': 48.6814,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 71.6433,
#   'Max Temp': 30.52,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 19.93,
#   'Country': 'KZ',
#   'Date': '2021-04-19 20:50:47'},
#  {'City': 'Syamzha',
#   'Lat': 60.0158,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 41.0614,
#   'Max Temp': 31.28,
#   'Humidity': 79,
#   'Cloudiness': 19,
#   'Wind Speed': 4.81,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:50:47'},
#  {'City': 'Kasongo',
#   'Lat': -4.45,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 26.6667,
#   'Max Temp': 69.85,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'CD',
#   'Date': '2021-04-19 20:50:47'},
#  {'City': 'Barra',
#   'Lat': -11.0894,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'Lng': -43.1417,
#   'Max Temp': 74.53,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:50:48'},
#  {'City': 'Perigueux',
#   'Lat': 45.1833,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 0.7167,
#   'Max Temp': 52,
#   'Humidity': 53,
#   'Cloudiness': 12,
#   'Wind Speed': 3.65,
#   'Country': 'FR',
#   'Date': '2021-04-19 20:50:48'},
#  {'City': 'Filadelfia',
#   'Lat': 39.9523,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -75.1638,
#   'Max Temp': 64,
#   'Humidity': 44,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-04-19 20:47:53'},
#  {'City': 'Atamanovka',
#   'Lat': 51.93,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': 113.63,
#   'Max Temp': 30.2,
#   'Humidity': 31,
#   'Cloudiness': 53,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:50:48'},
#  {'City': 'Manuk Mangkaw',
#   'Lat': 4.8,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 119.85,
#   'Max Temp': 82.67,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'PH',
#   'Date': '2021-04-19 20:50:49'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.9878,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'Lng': -74.9547,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'CO',
#   'Date': '2021-04-19 20:50:49'},
#  {'City': 'Gbarnga',
#   'Lat': 6.9956,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': -9.4722,
#   'Max Temp': 77.67,
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 4.5,
#   'Country': 'LR',
#   'Date': '2021-04-19 20:50:49'},
#  {'City': 'Altagracia De Orituco',
#   'Lat': 9.8601,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'Lng': -66.3814,
#   'Max Temp': 89.08,
#   'Humidity': 37,
#   'Cloudiness': 89,
#   'Wind Speed': 6.55,
#   'Country': 'VE',
#   'Date': '2021-04-19 20:50:50'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 131.25,
#   'Max Temp': 78.51,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 5.44,
#   'Country': 'ID',
#   'Date': '2021-04-19 20:46:50'},
#  {'City': 'Teguise',
#   'Lat': 29.0605,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': -13.564,
#   'Max Temp': 68,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'ES',
#   'Date': '2021-04-19 20:50:50'},
#  {'City': 'Farkhor',
#   'Lat': 37.4922,
#   'Weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'Lng': 69.4036,
#   'Max Temp': 59,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'TJ',
#   'Date': '2021-04-19 20:50:50'},
#  {'City': 'Concarneau',
#   'Lat': 47.875,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': -3.9225,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Date': '2021-04-19 20:50:51'},
#  {'City': 'Mangochi',
#   'Lat': -14.4782,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 35.2645,
#   'Max Temp': 68.22,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.36,
#   'Country': 'MW',
#   'Date': '2021-04-19 20:50:51'},
#  {'City': 'Tiganasi',
#   'Lat': 47.3333,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 27.4667,
#   'Max Temp': 50,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 5.01,
#   'Country': 'RO',
#   'Date': '2021-04-19 20:50:51'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': -10.0711,
#   'Max Temp': 83.46,
#   'Humidity': 7,
#   'Cloudiness': 2,
#   'Wind Speed': 4.81,
#   'Country': 'MR',
#   'Date': '2021-04-19 20:50:52'},
#  {'City': 'Hutchinson',
#   'Lat': 38.0608,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -97.9298,
#   'Max Temp': 51.8,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Date': '2021-04-19 20:46:52'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 124.2928,
#   'Max Temp': 73,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'PH',
#   'Date': '2021-04-19 20:47:33'},
#  {'City': 'Fort-Shevchenko',
#   'Lat': 44.5086,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 50.263,
#   'Max Temp': 55.96,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Country': 'KZ',
#   'Date': '2021-04-19 20:50:52'},
#  {'City': 'Sooke',
#   'Lat': 48.3746,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -123.7276,
#   'Max Temp': 63,
#   'Humidity': 58,
#   'Cloudiness': 67,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-04-19 20:50:52'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'Lng': 152.35,
#   'Max Temp': 66,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2021-04-19 20:50:53'},
#  {'City': 'Sarh',
#   'Lat': 9.1429,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 18.3923,
#   'Max Temp': 89.6,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Country': 'TD',
#   'Date': '2021-04-19 20:50:53'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -121.9166,
#   'Max Temp': 55.99,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-04-19 20:50:53'},
#  {'City': 'Lexington Park',
#   'Lat': 38.2668,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -76.4538,
#   'Max Temp': 55.99,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-04-19 20:50:54'},
#  {'City': 'Myitkyina',
#   'Lat': 25.3833,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 97.4,
#   'Max Temp': 65.44,
#   'Humidity': 87,
#   'Cloudiness': 6,
#   'Wind Speed': 2.33,
#   'Country': 'MM',
#   'Date': '2021-04-19 20:50:54'},
#  {'City': 'Nisko',
#   'Lat': 50.5199,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 22.1397,
#   'Max Temp': 48,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 3,
#   'Country': 'PL',
#   'Date': '2021-04-19 20:50:54'},
#  {'City': 'Oktyabrskoye',
#   'Lat': 43.0645,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 44.7417,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-04-19 20:50:19'},
#  {'City': 'Santa Isabel',
#   'Lat': -23.3156,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'Lng': -46.2214,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:50:55'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 23.3716,
#   'Max Temp': 60.87,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 12.77,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:50:55'},
#  {'City': 'Longuenesse',
#   'Lat': 50.734,
#   'Weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'Lng': 2.2352,
#   'Max Temp': 45,
#   'Humidity': 86,
#   'Cloudiness': 8,
#   'Wind Speed': 2.39,
#   'Country': 'FR',
#   'Date': '2021-04-19 20:50:55'},
#  {'City': 'Quang Ngai',
#   'Lat': 15.1167,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 108.8,
#   'Max Temp': 74.88,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'VN',
#   'Date': '2021-04-19 20:50:56'},
#  {'City': 'La Ligua',
#   'Lat': -32.4524,
#   'Weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'Lng': -71.2311,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CL',
#   'Date': '2021-04-19 20:50:56'},
#  {'City': 'Placido De Castro',
#   'Lat': -10.3353,
#   'Weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'Lng': -67.1856,
#   'Max Temp': 79.75,
#   'Humidity': 94,
#   'Cloudiness': 53,
#   'Wind Speed': 2.24,
#   'Country': 'BR',
#   'Date': '2021-04-19 20:50:56'},
#  {'City': 'Vredendal',
#   'Lat': -31.6683,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 18.5012,
#   'Max Temp': 72.52,
#   'Humidity': 53,
#   'Cloudiness': 94,
#   'Wind Speed': 4.63,
#   'Country': 'ZA',
#   'Date': '2021-04-19 20:50:56'},
#  {'City': 'Lindi',
#   'Lat': -10,
#   'Weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'Lng': 39.7167,
#   'Max Temp': 70.86,
#   'Humidity': 97,
#   'Cloudiness': 92,
#   'Wind Speed': 5.82,
#   'Country': 'TZ',
#   'Date': '2021-04-19 20:50:57'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat                                            Weather  \
# 0       Hobart -42.8794  [{'id': 803, 'main': 'Clouds', 'description': ...
# 1      Ushuaia -54.8000  [{'id': 501, 'main': 'Rain', 'description': 'm...
# 2    Karasburg -28.0167  [{'id': 800, 'main': 'Clear', 'description': '...
# 3    Cape Town -33.9258  [{'id': 800, 'main': 'Clear', 'description': '...
# 4       Barrow  71.2906  [{'id': 804, 'main': 'Clouds', 'description': ...
# 5      Huarmey -10.0681  [{'id': 804, 'main': 'Clouds', 'description': ...
# 6      Qaanaaq  77.4840  [{'id': 804, 'main': 'Clouds', 'description': ...
# 7        Rocha -34.4833  [{'id': 800, 'main': 'Clear', 'description': '...
# 8  Port Alfred -33.5906  [{'id': 804, 'main': 'Clouds', 'description': ...
# 9       Hinton  53.4001  [{'id': 800, 'main': 'Clear', 'description': '...
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0  147.3294     52.00        76          75        8.05      AU
# 1  -68.3000     44.60        87          75        5.75      AR
# 2   18.7500     72.23        24           6       11.50      NA
# 3   18.4232     63.00        72           0        5.75      ZA
# 4 -156.7887     24.80        80          90       20.71      US
# 5  -78.1522     73.40        72          99       11.07      PE
# 6  -69.3632      6.69        80         100        6.15      GL
# 7  -54.3333     63.05        83           0        7.85      UY
# 8   26.8910     64.33        74         100       11.61      ZA
# 9 -117.5857     46.40        27           5        4.61      CA
#
#                   Date
# 0  2021-04-19 20:46:29
# 1  2021-04-19 20:41:40
# 2  2021-04-19 20:47:56
# 3  2021-04-19 20:46:12
# 4  2021-04-19 20:41:19
# 5  2021-04-19 20:47:56
# 6  2021-04-19 20:46:14
# 7  2021-04-19 20:47:57
# 8  2021-04-19 20:46:31
# 9  2021-04-19 20:47:57

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                   City Country                 Date      Lat       Lng  \
# 0               Hobart      AU  2021-04-19 20:46:29 -42.8794  147.3294
# 1              Ushuaia      AR  2021-04-19 20:41:40 -54.8000  -68.3000
# 2            Karasburg      NA  2021-04-19 20:47:56 -28.0167   18.7500
# 3            Cape Town      ZA  2021-04-19 20:46:12 -33.9258   18.4232
# 4               Barrow      US  2021-04-19 20:41:19  71.2906 -156.7887
# ..                 ...     ...                  ...      ...       ...
# 688         Quang Ngai      VN  2021-04-19 20:50:56  15.1167  108.8000
# 689           La Ligua      CL  2021-04-19 20:50:56 -32.4524  -71.2311
# 690  Placido De Castro      BR  2021-04-19 20:50:56 -10.3353  -67.1856
# 691          Vredendal      ZA  2021-04-19 20:50:56 -31.6683   18.5012
# 692              Lindi      TZ  2021-04-19 20:50:57 -10.0000   39.7167
#
#      Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       52.00        76          75        8.05
# 1       44.60        87          75        5.75
# 2       72.23        24           6       11.50
# 3       63.00        72           0        5.75
# 4       24.80        80          90       20.71
# ..        ...       ...         ...         ...
# 688     74.88        89         100        3.51
# 689     59.00        82          75       11.50
# 690     79.75        94          53        2.24
# 691     72.52        53          94        4.63
# 692     70.86        97          92        5.82
#
#                                                Weather
# 0    [{'id': 803, 'main': 'Clouds', 'description': ...
# 1    [{'id': 501, 'main': 'Rain', 'description': 'm...
# 2    [{'id': 800, 'main': 'Clear', 'description': '...
# 3    [{'id': 800, 'main': 'Clear', 'description': '...
# 4    [{'id': 804, 'main': 'Clouds', 'description': ...
# ..                                                 ...
# 688  [{'id': 804, 'main': 'Clouds', 'description': ...
# 689  [{'id': 803, 'main': 'Clouds', 'description': ...
# 690  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 691  [{'id': 804, 'main': 'Clouds', 'description': ...
# 692  [{'id': 804, 'main': 'Clouds', 'description': ...
#
# [693 rows x 10 columns]

# %%
weather_series = city_data_df["Weather"]
weather_series
# Out:
# 0      [{'id': 803, 'main': 'Clouds', 'description': ...
# 1      [{'id': 501, 'main': 'Rain', 'description': 'm...
# 2      [{'id': 800, 'main': 'Clear', 'description': '...
# 3      [{'id': 800, 'main': 'Clear', 'description': '...
# 4      [{'id': 804, 'main': 'Clouds', 'description': ...
#                              ...
# 688    [{'id': 804, 'main': 'Clouds', 'description': ...
# 689    [{'id': 803, 'main': 'Clouds', 'description': ...
# 690    [{'id': 500, 'main': 'Rain', 'description': 'l...
# 691    [{'id': 804, 'main': 'Clouds', 'description': ...
# 692    [{'id': 804, 'main': 'Clouds', 'description': ...
# Name: Weather, Length: 693, dtype: object

# %%
weather_series_new = [i[0] for i in weather_series]
weather_series_new
# Out:
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 502,
#   'main': 'Rain',
#   'description': 'heavy intensity rain',
#   'icon': '10n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 502,
#   'main': 'Rain',
#   'description': 'heavy intensity rain',
#   'icon': '10d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 502,
#   'main': 'Rain',
#   'description': 'heavy intensity rain',
#   'icon': '10n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'},
#  {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 502,
#   'main': 'Rain',
#   'description': 'heavy intensity rain',
#   'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'},
#  {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'},
#  {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'},
#  {'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04n'}]

# %%
for weather_series in weather_series_new:
    del weather_series["id"]
    del weather_series["main"]
    del weather_series["icon"]

# %%
weather_series_new
# Out:
# [{'description': 'broken clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light snow'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'light rain'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'broken clouds'},
#  {'description': 'heavy intensity rain'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'snow'},
#  {'description': 'light rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'moderate rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'light snow'},
#  {'description': 'scattered clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'light snow'},
#  {'description': 'clear sky'},
#  {'description': 'light snow'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'snow'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'snow'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'light rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'light snow'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light snow'},
#  {'description': 'light rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'fog'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'haze'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'light snow'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'snow'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'snow'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'haze'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light snow'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'moderate rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'heavy intensity rain'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'heavy intensity rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'haze'},
#  {'description': 'mist'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light snow'},
#  {'description': 'light snow'},
#  {'description': 'clear sky'},
#  {'description': 'snow'},
#  {'description': 'few clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'snow'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'light snow'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'heavy intensity rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'light snow'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'fog'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'snow'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'scattered clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'scattered clouds'},
#  {'description': 'moderate rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'light snow'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'snow'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'light rain'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'few clouds'},
#  {'description': 'few clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'clear sky'},
#  {'description': 'broken clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'overcast clouds'},
#  {'description': 'clear sky'},
#  {'description': 'overcast clouds'},
#  {'description': 'broken clouds'},
#  {'description': 'light rain'},
#  {'description': 'overcast clouds'},
#  {'description': 'overcast clouds'}]

# %%
weather_series_new_df = pd.DataFrame(weather_series_new)
weather_series_new_df
# Out:
#          description
# 0      broken clouds
# 1      moderate rain
# 2          clear sky
# 3          clear sky
# 4    overcast clouds
# ..               ...
# 688  overcast clouds
# 689    broken clouds
# 690       light rain
# 691  overcast clouds
# 692  overcast clouds
#
# [693 rows x 1 columns]

# %%
final_df = city_data_df.merge(weather_series_new_df, left_index=True, right_index=True)
final_df
# Out:
#                   City Country                 Date      Lat       Lng  \
# 0               Hobart      AU  2021-04-19 20:46:29 -42.8794  147.3294
# 1              Ushuaia      AR  2021-04-19 20:41:40 -54.8000  -68.3000
# 2            Karasburg      NA  2021-04-19 20:47:56 -28.0167   18.7500
# 3            Cape Town      ZA  2021-04-19 20:46:12 -33.9258   18.4232
# 4               Barrow      US  2021-04-19 20:41:19  71.2906 -156.7887
# ..                 ...     ...                  ...      ...       ...
# 688         Quang Ngai      VN  2021-04-19 20:50:56  15.1167  108.8000
# 689           La Ligua      CL  2021-04-19 20:50:56 -32.4524  -71.2311
# 690  Placido De Castro      BR  2021-04-19 20:50:56 -10.3353  -67.1856
# 691          Vredendal      ZA  2021-04-19 20:50:56 -31.6683   18.5012
# 692              Lindi      TZ  2021-04-19 20:50:57 -10.0000   39.7167
#
#      Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       52.00        76          75        8.05
# 1       44.60        87          75        5.75
# 2       72.23        24           6       11.50
# 3       63.00        72           0        5.75
# 4       24.80        80          90       20.71
# ..        ...       ...         ...         ...
# 688     74.88        89         100        3.51
# 689     59.00        82          75       11.50
# 690     79.75        94          53        2.24
# 691     72.52        53          94        4.63
# 692     70.86        97          92        5.82
#
#                                   Weather      description
# 0      [{'description': 'broken clouds'}]    broken clouds
# 1      [{'description': 'moderate rain'}]    moderate rain
# 2          [{'description': 'clear sky'}]        clear sky
# 3          [{'description': 'clear sky'}]        clear sky
# 4    [{'description': 'overcast clouds'}]  overcast clouds
# ..                                    ...              ...
# 688  [{'description': 'overcast clouds'}]  overcast clouds
# 689    [{'description': 'broken clouds'}]    broken clouds
# 690       [{'description': 'light rain'}]       light rain
# 691  [{'description': 'overcast clouds'}]  overcast clouds
# 692  [{'description': 'overcast clouds'}]  overcast clouds
#
# [693 rows x 11 columns]

# %%
del final_df["Weather"]
del final_df["Date"]
final_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hobart      AU -42.8794  147.3294     52.00        76
# 1              Ushuaia      AR -54.8000  -68.3000     44.60        87
# 2            Karasburg      NA -28.0167   18.7500     72.23        24
# 3            Cape Town      ZA -33.9258   18.4232     63.00        72
# 4               Barrow      US  71.2906 -156.7887     24.80        80
# ..                 ...     ...      ...       ...       ...       ...
# 688         Quang Ngai      VN  15.1167  108.8000     74.88        89
# 689           La Ligua      CL -32.4524  -71.2311     59.00        82
# 690  Placido De Castro      BR -10.3353  -67.1856     79.75        94
# 691          Vredendal      ZA -31.6683   18.5012     72.52        53
# 692              Lindi      TZ -10.0000   39.7167     70.86        97
#
#      Cloudiness  Wind Speed      description
# 0            75        8.05    broken clouds
# 1            75        5.75    moderate rain
# 2             6       11.50        clear sky
# 3             0        5.75        clear sky
# 4            90       20.71  overcast clouds
# ..          ...         ...              ...
# 688         100        3.51  overcast clouds
# 689          75       11.50    broken clouds
# 690          53        2.24       light rain
# 691          94        4.63  overcast clouds
# 692          92        5.82  overcast clouds
#
# [693 rows x 9 columns]

# %%
final_df.columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
final_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hobart      AU -42.8794  147.3294     52.00        76
# 1              Ushuaia      AR -54.8000  -68.3000     44.60        87
# 2            Karasburg      NA -28.0167   18.7500     72.23        24
# 3            Cape Town      ZA -33.9258   18.4232     63.00        72
# 4               Barrow      US  71.2906 -156.7887     24.80        80
# ..                 ...     ...      ...       ...       ...       ...
# 688         Quang Ngai      VN  15.1167  108.8000     74.88        89
# 689           La Ligua      CL -32.4524  -71.2311     59.00        82
# 690  Placido De Castro      BR -10.3353  -67.1856     79.75        94
# 691          Vredendal      ZA -31.6683   18.5012     72.52        53
# 692              Lindi      TZ -10.0000   39.7167     70.86        97
#
#      Cloudiness  Wind Speed Current Description
# 0            75        8.05       broken clouds
# 1            75        5.75       moderate rain
# 2             6       11.50           clear sky
# 3             0        5.75           clear sky
# 4            90       20.71     overcast clouds
# ..          ...         ...                 ...
# 688         100        3.51     overcast clouds
# 689          75       11.50       broken clouds
# 690          53        2.24          light rain
# 691          94        4.63     overcast clouds
# 692          92        5.82     overcast clouds
#
# [693 rows x 9 columns]

# %%
len(final_df)
# Out:
# 693

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
